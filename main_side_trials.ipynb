# %%
# %%capture

# !pip install tqdm

# %%
# %%capture

# !pip install librosa

# %%
# %%capture

# !pip install tensorboard

# %%
import os
import random
from tqdm import tqdm
from datetime import date
import pandas as pd
import numpy as np
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.metrics import Metric

# %%
transcription_filepath = "C:\\Users\\Rhythex-Ak\\Documents\\dummy-kep\\Pels\\aud-ml\\transcriptions-audios-colab.xlsx"
audio_folder = "C:\\Users\\Rhythex-Ak\\Documents\\dummy-kep\\Pels\\aud-ml\\wav-audios"

# %%
print("Number of GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Number of GPUs Available:  0

# %% [markdown]
# # **Transcripts**

# %%
# Twi Alphabet :: AaBbDdEeƐɛFfGgHhIiKkLlMmNnOoƆɔPpRrSsTtUuWwYy

# %%
# Read transcription file
transcription_df = pd.read_excel(transcription_filepath)

# %%
# Read transcription file
transcription_df = pd.read_excel(transcription_filepath)

# %%
transcription_df.shape
# Out:
# (7514, 17)

# %%
transcription_df.head(5)
# Out:
#    unamed  File No.            IMAGE_PATH  \
# 0    1030      5599  Akan/images/0001.jpg
# 1    2724      2435  Akan/images/0001.jpg
# 2    2278         1  Akan/images/0001.jpg
# 3    2406      3167  Akan/images/0001.jpg
# 4    1367      6332  Akan/images/0001.jpg
#
#                                        IMAGE_SRC_URL  \
# 0  https://live.staticflickr.com/7846/46666781031...
# 1  https://live.staticflickr.com/7846/46666781031...
# 2  https://live.staticflickr.com/7846/46666781031...
# 3  https://live.staticflickr.com/7846/46666781031...
# 4  https://live.staticflickr.com/7846/46666781031...
#
#                                           AUDIO_PATH  \
# 0  Akan\selected transcribed audios\audios\ak_gh_...
# 1  Akan\selected transcribed audios\audios\ak_gh_...
# 2  Akan\selected transcribed audios\audios\ak_gh_...
# 3  Akan\selected transcribed audios\audios\ak_gh_...
# 4  Akan\selected transcribed audios\audios\ak_gh_...
#
#                                       Transcriptions  SPEAKER_ID  \
# 0  Funu adaka si fam. Mmeranteɛ ne mmabaawa bi te...        4625
# 1  Aborɔfokuo bi abɔ dɔnpem wɔ asieyɛ. Ɛfunu adak...        5097
# 2  Nnipadɔm bi atwa ahyia wɔ beaeɛ bi, na efunu a...          76
# 3  Nnipa bebree gyina hɔ wɔhyɛ ataade tuntum. Bin...          17
# 4  Nnipa bebree ahyia mu wɔ beaeɛ baako. Bebree n...          21
#
#               ORG_NAME PROJECT_NAME LOCALE  GENDER  AGE  \
# 0  University of Ghana        Waxal  ak_gh  Female   25
# 1  University of Ghana        Waxal  ak_gh  Female   25
# 2  University of Ghana        Waxal  ak_gh    Male   66
# 3  University of Ghana        Waxal  ak_gh  Female   21
# 4  University of Ghana        Waxal  ak_gh  Female   20
#
#                                   DEVICE ENVIRONMENT  YEAR  \
# 0  INFINIX MOBILITY LIMITED Infinix X690      Indoor  2023
# 1                       samsung SM-G960U      Indoor  2023
# 2                       samsung SM-J410F      Indoor  2023
# 3         TECNO MOBILE LIMITED TECNO KE5      Indoor  2023
# 4         TECNO MOBILE LIMITED TECNO KE5      Indoor  2023
#
#                                    Full Filename  \
# 0    ak_gh_image_0001_u238_1_1680183655166_05599
# 1    ak_gh_image_0001_u709_1_1681976769788_02435
# 2  ak_gh_image_0001_u11919_2_1688630906868_00001
# 3    ak_gh_image_0001_u133_1_1687352121107_03167
# 4    ak_gh_image_0001_u177_1_1687363796955_06332
#
#                                       Filename
# 0    ak_gh_image_0001_u238_1_1680183655166.mp3
# 1    ak_gh_image_0001_u709_1_1681976769788.mp3
# 2  ak_gh_image_0001_u11919_2_1688630906868.mp3
# 3    ak_gh_image_0001_u133_1_1687352121107.mp3
# 4    ak_gh_image_0001_u177_1_1687363796955.mp3

# %%
transcription_df['lower-transcriptions'] = transcription_df['Transcriptions'].str.lower().str.strip()

# %%
transcription_df.head(5)
# Out:
#    unamed  File No.            IMAGE_PATH  \
# 0    1030      5599  Akan/images/0001.jpg
# 1    2724      2435  Akan/images/0001.jpg
# 2    2278         1  Akan/images/0001.jpg
# 3    2406      3167  Akan/images/0001.jpg
# 4    1367      6332  Akan/images/0001.jpg
#
#                                        IMAGE_SRC_URL  \
# 0  https://live.staticflickr.com/7846/46666781031...
# 1  https://live.staticflickr.com/7846/46666781031...
# 2  https://live.staticflickr.com/7846/46666781031...
# 3  https://live.staticflickr.com/7846/46666781031...
# 4  https://live.staticflickr.com/7846/46666781031...
#
#                                           AUDIO_PATH  \
# 0  Akan\selected transcribed audios\audios\ak_gh_...
# 1  Akan\selected transcribed audios\audios\ak_gh_...
# 2  Akan\selected transcribed audios\audios\ak_gh_...
# 3  Akan\selected transcribed audios\audios\ak_gh_...
# 4  Akan\selected transcribed audios\audios\ak_gh_...
#
#                                       Transcriptions  SPEAKER_ID  \
# 0  Funu adaka si fam. Mmeranteɛ ne mmabaawa bi te...        4625
# 1  Aborɔfokuo bi abɔ dɔnpem wɔ asieyɛ. Ɛfunu adak...        5097
# 2  Nnipadɔm bi atwa ahyia wɔ beaeɛ bi, na efunu a...          76
# 3  Nnipa bebree gyina hɔ wɔhyɛ ataade tuntum. Bin...          17
# 4  Nnipa bebree ahyia mu wɔ beaeɛ baako. Bebree n...          21
#
#               ORG_NAME PROJECT_NAME LOCALE  GENDER  AGE  \
# 0  University of Ghana        Waxal  ak_gh  Female   25
# 1  University of Ghana        Waxal  ak_gh  Female   25
# 2  University of Ghana        Waxal  ak_gh    Male   66
# 3  University of Ghana        Waxal  ak_gh  Female   21
# 4  University of Ghana        Waxal  ak_gh  Female   20
#
#                                   DEVICE ENVIRONMENT  YEAR  \
# 0  INFINIX MOBILITY LIMITED Infinix X690      Indoor  2023
# 1                       samsung SM-G960U      Indoor  2023
# 2                       samsung SM-J410F      Indoor  2023
# 3         TECNO MOBILE LIMITED TECNO KE5      Indoor  2023
# 4         TECNO MOBILE LIMITED TECNO KE5      Indoor  2023
#
#                                    Full Filename  \
# 0    ak_gh_image_0001_u238_1_1680183655166_05599
# 1    ak_gh_image_0001_u709_1_1681976769788_02435
# 2  ak_gh_image_0001_u11919_2_1688630906868_00001
# 3    ak_gh_image_0001_u133_1_1687352121107_03167
# 4    ak_gh_image_0001_u177_1_1687363796955_06332
#
#                                       Filename  \
# 0    ak_gh_image_0001_u238_1_1680183655166.mp3
# 1    ak_gh_image_0001_u709_1_1681976769788.mp3
# 2  ak_gh_image_0001_u11919_2_1688630906868.mp3
# 3    ak_gh_image_0001_u133_1_1687352121107.mp3
# 4    ak_gh_image_0001_u177_1_1687363796955.mp3
#
#                                 lower-transcriptions
# 0  funu adaka si fam. mmeranteɛ ne mmabaawa bi te...
# 1  aborɔfokuo bi abɔ dɔnpem wɔ asieyɛ. ɛfunu adak...
# 2  nnipadɔm bi atwa ahyia wɔ beaeɛ bi, na efunu a...
# 3  nnipa bebree gyina hɔ wɔhyɛ ataade tuntum. bin...
# 4  nnipa bebree ahyia mu wɔ beaeɛ baako. bebree n...

# %%
# transcription_df['char-count'] =  len(transcription_df['lower-transcriptions'].str)

# %%
labels_uniq = [sentence for sentence in transcription_df['lower-transcriptions']]

# %%
# for item in labels_uniq:
#   print(item)

# %% [markdown]
# ## **Encoding transcript tokens**

# %%
class TextTransform:
    def __init__(self):
        self.char_to_num_dict =  {
      "а": 1, "b": 2, "d": 3, "e": 4, "ɛ": 5, "f": 6, "g": 7, "h": 8, "i": 9, "k": 10, "l": 11,
      "m": 12, "n": 13, "o": 14, "ɔ": 15, "p": 16, "r": 17, "s": 18, "t": 19, "u": 20, "w": 21,
      "y": 22, " ": 23}

        self.index_map = {}
        for key, value in self.char_to_num_dict.items():
            self.index_map[value] = key


    # Encode Character to Numbers
    def char_to_num(self, sentence):
        num_sent = np.zeros(5000) #number of characters of the longest text <==> 416, 5000
        i = 0
        for char in sentence.lower():
            if char in self.char_to_num_dict.keys():
                num_sent[i]=self.char_to_num_dict[char]
            i += 1
        return num_sent

    # Decode Character to Numbers
    def num_to_char(self, sentence):
        char_sent = np.array()
        i = 0
        for num in sentence:
            char_sent[i]=self.index_map[num]
            i += 1
        return char_sent

# %%
text_transform = TextTransform()

labels = []
for label in labels_uniq:
    labels.append(label)
    labels.append(label)

labels = list(map(text_transform.char_to_num, labels))

# %%
# type(labels)
# Out:
# list

# %%
# %%capture
labels

# %% [markdown]
# # **Audio**

# %%
# Function to load audio using librosa

def load_audio(audio_filepath):
    audio, sample_rate = librosa.load(audio_filepath, sr=None, mono=True)

      # Print the shape of the audio waveform and the sample rate
    print("Audio Shape:", audio.shape)
    print("Sample Rate:", sample_rate)


    return audio, sample_rate

# %%
def play_audio(audio_filepath):
  return ipd.Audio(f"{audio_filepath}")

# %%
# Get audio file names
audio_files = os.listdir(audio_folder)
# audio_files

# %%
number_of_audios = len(audio_files)
print(f"Number of audio files: {number_of_audios}")
# Out:
# Number of audio files: 7514

# %% [markdown]
# ### **Inspecting Random Audio Samples**

# %%
# Selecting a random audio file
random_audio_filename = random.choice(audio_files)
random_audio_filename
# Out:
# 'ak_gh_image_0072_u192_1_1679833805392_10400.wav'

# %%
random_audio_filepath = os.path.join(audio_folder, f"{random_audio_filename}")
random_audio_filepath
# Out:
# 'C:\\Users\\Rhythex-Ak\\Documents\\dummy-kep\\Pels\\aud-ml\\wav-audios\\ak_gh_image_0072_u192_1_1679833805392_10400.wav'

# %%
play_audio(random_audio_filepath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_audio, samp_rate = load_audio(random_audio_filepath)
# Out:
# Audio Shape: (323200,)
# Sample Rate: 16000

# %%
duration = librosa.get_duration(path=f"{random_audio_filepath}")
print(f"The duration of the audio is {duration} ")
# Out:
# The duration of the audio is 20.2

# %% [markdown]
# ## **Waveform**

# %%
# Waveplot to  know the loudness of the audio at a given time

# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(10, 5))

librosa.display.waveshow(sample_audio, sr=samp_rate, color="blue")

# Set the title of the plot
plt.title('Waveform')
plt.xlabel("Time")
plt.ylabel("Amplitude")

# Show the plot
plt.show()

# %% [markdown]
# ## **MelSpectogram**

# %%
def imageSpecificatons(ms_feature):
    fig, ax = plt.subplots()
    ms_dB = librosa.power_to_db(ms_feature, ref=np.max)
    print(ms_feature.shape)
    img = librosa.display.specshow(ms_dB, x_axis='time', y_axis='mel', ax=ax)
    fig.colorbar(img, ax=ax, format='%+2.0f dB')
    ax.set(title='Mel-frequency spectrogram');



def wav2melSpec(AUDIO_PATH):
    audio, sr = librosa.load(AUDIO_PATH)
    return librosa.feature.melspectrogram(y=audio, sr=sr)



def get_audio_info(path, show_melspec=False, label=None):
    spec = wav2melSpec(path)
    if label is not None:
        print("Label:", label)
    if show_melspec is not False:
        imageSpecificatons(spec)

# %%
get_audio_info(random_audio_filepath, show_melspec=True)
# Out:
# (128, 870)

# %% [markdown]
# ## **Audio Preprocessing**

# %%
def audioEncoder(audio_wave, max_len=None, number_MFCC_features=14, sampling_rate=16000):
    # Compute MFCC features
    mfcc = librosa.feature.mfcc(y=audio_wave, n_mfcc=number_MFCC_features, sr=sampling_rate)

    # Determine the length to use for MFCC features
    if max_len is not None:
        # If max_len is specified, apply padding or truncation
        if max_len > mfcc.shape[1]:
            # Pad MFCC features with zeros to match max_len
            pad_width = max_len - mfcc.shape[1]
            mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            # Truncate MFCC features to max_len
            mfcc = mfcc[:, :max_len]

    return mfcc

# %%
files_in_dir = os.listdir(audio_folder)

# %%
mfcc_spec_values = []

# %%
for file_name in tqdm(files_in_dir):
  # with tf.device('/GPU:0'):
  audio_path = os.path.join(audio_folder, file_name)

  # Load the audio file and extract the audio waveform and sampling rate
  audio_waveform, sr = librosa.load(audio_path, sr=None)

  # Compute MFCC features for the original audio waveform
  original_mfcc = audioEncoder(audio_waveform, max_len=2000)

  # Expand dimensions to create a spectrogram (MFCC representation) for the original audio
  original_spectrogram = np.expand_dims(original_mfcc, -1)

  # Append the original MFCC spectrogram to the list of spectrograms
  mfcc_spec_values.append(original_spectrogram)

  # Apply pitch shifting to the audio waveform
  pitch_shifted_waveform = librosa.effects.pitch_shift(audio_waveform, sr=16000, n_steps=10)

  # Compute MFCC features for the pitch-shifted audio waveform
  shifted_mfcc = audioEncoder(pitch_shifted_waveform, max_len=2000)

  # Expand dimensions to create a spectrogram (MFCC representation) for the pitch-shifted audio
  shifted_spectrogram = np.expand_dims(shifted_mfcc, -1)

  # Append the pitch-shifted MFCC spectrogram to the list of spectrograms
  mfcc_spec_values.append(shifted_spectrogram)
# Out:
# 100%|██████████| 7514/7514 [37:50<00:00,  3.31it/s]

# %%
mfcc_values_array = np.array(mfcc_spec_values)
print("Shape of mfcc_values:", mfcc_values_array.shape)

# mfcc_spectograms
# Out:
# Shape of mfcc_values: (15028, 14, 2000, 1)

# %%
def cut_array(text_arr):
    return text_arr[:1756]

# Split data into train and test sets
audio_train, text_train = np.array(mfcc_spec_values[:11228]), np.array(list(map(cut_array, labels[:11228])))
audio_test, text_test = np.array(mfcc_spec_values[11228:]), np.array(list(map(cut_array, labels[11228:])))

# Min-Max normalization for audio_train
min_value = np.min(audio_train)
max_value = np.max(audio_train)
audio_train_normalized = (audio_train - min_value) / (max_value - min_value)

# Min-Max normalization for audio_test
audio_test_normalized = (audio_test - min_value) / (max_value - min_value)

# %%
print(audio_train.shape, audio_train_normalized.shape, text_train.shape, audio_test.shape, audio_test_normalized.shape, text_test.shape)
# Out:
# (11228, 14, 2000, 1) (11228, 14, 2000, 1) (11228, 1756) (3800, 14, 2000, 1) (3800, 14, 2000, 1) (3800, 1756)

# %% [markdown]
# ## **Building Model: Convolutional Neural Network**

# %%
dropout = 0.15
input_dim = (14, 2000,1)
output_dim_vocab = 23
output_dim = 1756


model = Sequential([
  layers.Conv2D(filters=32, kernel_size=[6, 6], strides=[2, 2],input_shape=input_dim, padding="same", use_bias=False),
  layers.BatchNormalization(),
  layers.Activation(activation='leaky_relu'),
  layers.MaxPooling2D(pool_size=(3,3)),
  layers.Dropout(dropout),
  # 2 convolutional layer
  layers.Conv2D(128,(3,3),padding='same'),
  layers.BatchNormalization(),
  layers.Activation(activation='relu'),
#   layers.MaxPooling2D(pool_size=(2,2)),
  layers.Dropout(dropout),
  # 3 convolutional  layer
  layers.Conv2D(512,(3,3),padding='same'),
  layers.BatchNormalization(),
  layers.Activation(activation='relu'),
  layers.MaxPooling2D(pool_size=(2,2)),
  layers.Dropout(dropout),
  # 4 convolutional  layer
  layers.Conv2D(512,(3,3),padding='same'),
  layers.BatchNormalization(),
  layers.Activation(activation='relu'),
#   layers.MaxPooling2D(pool_size=(2,2)),
  layers.Dropout(dropout),
  layers.Dense(512),
  layers.Activation(activation='leaky_relu'),
  layers.Dropout(dropout),
  layers.Conv2D(filters=32, kernel_size=[6, 6], strides=[1, 1], padding="same", use_bias=False),
#   fully connected layer with 256 nuerons
  layers.Flatten(),
  layers.Dense(256, activation="softmax"),
  layers.BatchNormalization(),
  layers.Dropout(dropout),
  layers.Activation(activation='relu'),
#   fully connected layer with 512 nuerons
  layers.Dense(output_dim_vocab, activation="softmax"),
  layers.Dense(512, activation="softmax"),
  layers.BatchNormalization(),
  layers.Dropout(dropout),
  layers.Activation(activation='relu'),
#     output layer
  layers.Dense(output_dim, activation="softmax"),
])
# Out:
# c:\Users\Rhythex-Ak\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %% [markdown]
# ### **Loss Function for Model training**

# %%
def CTCLoss(y_true, y_pred):
  # Connectionist Temporal Classification loss
    batch_len = tf.cast(tf.shape(y_true)[0],dtype = 'int64')
    input_length = tf.cast(tf.shape(y_pred)[1],dtype = 'int64')
    label_length = tf.cast(tf.shape(y_true)[1],dtype = 'int64')

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype = 'int64')
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype = 'int64')
    loss = keras.backend.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %% [markdown]
# ### **Running Tensorboard**

# %%
# %load_ext tensorboard

# %%
# !rm -rf 'C:\Users\Rhythex-Ak\Documents\dummy-kep\Pels\aud-ml'

# %% [markdown]
# ### **Model Summary**

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
#     loss=CTCLoss,
#     metrics=[CERMetric(), WERMetric()],
#     metrics=EditDistance())
    metrics=['accuracy'])

# %%
model_path = 'C:\\Users\\Rhythex-Ak\\Documents\\dummy-kep\\Pels\\aud-ml\\models'
mp = os.path.join(model_path, f"model-{str(date.today())}.keras")
mp
# Out:
# 'C:\\Users\\Rhythex-Ak\\Documents\\dummy-kep\\Pels\\aud-ml\\models\\model-2024-04-26.keras'

# %%
# Define callbacks

earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
checkpoint = ModelCheckpoint(mp, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
tb_callback = TensorBoard(f'{model_path}/logs', write_graph=True, write_steps_per_second=True, update_freq=1)
reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, min_delta=1e-10, patience=5, verbose=1, mode='auto')
csv_logs = CSVLogger(f"{model_path}/logs/my_logs.csv", separator=",", append=False)


callbackList = [earlystopper, checkpoint, tb_callback, reduceLROnPlat, csv_logs]

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 7, 1000, 32)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 1000, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 7, 1000, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 2, 333, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2, 333, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 2, 333, 128)    │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 2, 333, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 2, 333, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2, 333, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 2, 333, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 2, 333, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 2, 333, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 1, 166, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1, 166, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 1, 166, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1, 166, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1, 166, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1, 166, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1, 166, 512)    │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 1, 166, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1, 166, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 1, 166, 32)     │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 5312)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │     1,360,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 23)             │         5,911 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │        12,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1756)           │       900,828 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,127,731 (23.38 MB)
#  Trainable params: 6,123,827 (23.36 MB)
#  Non-trainable params: 3,904 (15.25 KB)

# %% [markdown]
# ## **Model Training**

# %%
# Train the model
# with tf.device('/GPU:0'):
history = model.fit(
    x=audio_train,
    y=text_train,
    validation_split=0.2,
    epochs=20,
    batch_size=32,
    callbacks= callbackList
)
# Out:
# Epoch 1/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.4604e-04 - loss: 13366.7852
# Epoch 1: val_loss improved from inf to 12373.76367, saving model to C:\Users\Rhythex-Ak\Documents\dummy-kep\Pels\aud-ml\models\model-2024-04-26.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 1.4631e-04 - loss: 13362.9307 - val_accuracy: 0.0000e+00 - val_loss: 12373.7637 - learning_rate: 0.0010
# Epoch 2/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 9.4488e-04 - loss: 13145.3818
# Epoch 2: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 433s 2s/step - accuracy: 9.4430e-04 - loss: 13149.2451 - val_accuracy: 0.0000e+00 - val_loss: 17576.2070 - learning_rate: 0.0010
# Epoch 3/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.1920e-06 - loss: 19078.4512
# Epoch 3: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 430s 2s/step - accuracy: 1.5826e-06 - loss: 19085.6895 - val_accuracy: 0.0000e+00 - val_loss: 25994.5078 - learning_rate: 0.0010
# Epoch 4/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0023 - loss: 27391.6582
# Epoch 4: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 429s 2s/step - accuracy: 0.0023 - loss: 27403.3574 - val_accuracy: 0.0000e+00 - val_loss: 37852.0078 - learning_rate: 0.0010
# Epoch 5/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 6.6268e-05 - loss: 39969.9648
# Epoch 5: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 427s 2s/step - accuracy: 6.8402e-05 - loss: 39981.6953 - val_accuracy: 0.0000e+00 - val_loss: 52228.1797 - learning_rate: 0.0010
# Epoch 6/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0109 - loss: 53806.8984
# Epoch 6: val_loss did not improve from 12373.76367
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 430s 2s/step - accuracy: 0.0109 - loss: 53823.0625 - val_accuracy: 0.0000e+00 - val_loss: 69236.5625 - learning_rate: 0.0010
# Epoch 7/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 8.5993e-05 - loss: 71796.2422
# Epoch 7: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 438s 2s/step - accuracy: 8.7267e-05 - loss: 71801.4375 - val_accuracy: 0.0000e+00 - val_loss: 84207.4844 - learning_rate: 8.0000e-04
# Epoch 8/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 4.2430e-04 - loss: 85796.9688
# Epoch 8: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 446s 2s/step - accuracy: 4.2832e-04 - loss: 85805.2500 - val_accuracy: 0.0178 - val_loss: 100048.4453 - learning_rate: 8.0000e-04
# Epoch 9/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0047 - loss: 102969.7969
# Epoch 9: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 431s 2s/step - accuracy: 0.0047 - loss: 102972.3281 - val_accuracy: 0.0178 - val_loss: 117608.1719 - learning_rate: 8.0000e-04
# Epoch 10/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0025 - loss: 115083.4844
# Epoch 10: val_loss did not improve from 12373.76367
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 427s 2s/step - accuracy: 0.0025 - loss: 115107.5312 - val_accuracy: 0.0178 - val_loss: 135466.3281 - learning_rate: 8.0000e-04
# Epoch 11/20
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0016 - loss: 135787.8125
# Epoch 11: val_loss did not improve from 12373.76367
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 425s 2s/step - accuracy: 0.0016 - loss: 135800.7188 - val_accuracy: 0.0178 - val_loss: 154800.0781 - learning_rate: 8.0000e-04
# Epoch 11: early stopping

# %%
# %tensorboard --logdir "C:\Users\Rhythex-Ak\Documents\dummy-kep\Pels\aud-ml\models\logs\train"
# Out:
# Reusing TensorBoard on port 6007 (pid 23176), started 2:29:37 ago. (Use '!kill 23176' to kill it.)
#       <iframe id="tensorboard-frame-7ee2f41565c45927" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7ee2f41565c45927");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## **Loading Pretrained Model**

# %%
# model_filepath = "/content/drive/MyDrive/Colab Notebooks/aud-ml-datasets/mod/best-model.h5"
# mp = os.path.join(model_path, f"model-{str(date.today())}.h5")

# %%
# new_model = tf.keras.models.load_model(f'{model_filepath}')

# %%
# loss, acc = model.evaluate(audio_test, text_test, verbose=0)

# %%
# print(f"test accuracy {acc*100}, test loss {loss*100}")

# %% [markdown]
# ## **Model Performance**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# ________________ Graph 1 -------------------------

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
# ________________ Graph 2 -------------------------

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Categorical crossentropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# val_loss

# %% [markdown]
# ## **Model Predictions**

# %%
loss, acc = model.evaluate(audio_test, text_test, verbose=0)

# %%
print(acc)

# %%
print(f"test accuracy {acc*100}, test loss {loss*100}")
# Out:
# test accuracy 0.5789473652839661, test loss 12938417.1875

# %%
audio_predict = model.predict(audio_test)
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 28s 230ms/step

# %%
# text_predict = model.predict(text_test)

# %%
print(audio_predict.ndim)
# Out:
# 2

# %%
print(len(audio_predict))
# Out:
# 3800

# %% [markdown]
# ## **Decoding Model Predictions**

# %%
import numpy as np

def greedy_decode(pred):
    # Convert softmax probabilities to predicted character indices
    char_indices = np.argmax(pred, axis=-1)

    # Map indices back to characters using your character mapping or TextTransform
    predicted_text = text_transform.num_to_char(char_indices)

    return predicted_text

# %%
# Decode the predictions using greedy decoding
predicted_text = greedy_decode(predict)

print(predicted_text)

# %% [markdown]
# This code has been adapted from;
# https://www.kaggle.com/code/yanapple/speech-to-text-summer-project
